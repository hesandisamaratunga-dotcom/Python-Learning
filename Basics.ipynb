# %%
print("Hello World")
# Out:
# Hello World

# %%
import sys

print(sys.version)
# Out:
# 3.14.4 (tags/v3.14.4:23116f9, Apr  7 2026, 14:10:54) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# --Python Indentation--
#
# Indentation refers to the spaces at the beginning of a code line.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# Python uses indentation to indicate a block of code.
#
# IMPORTANT:
# The number of spaces is up to you as a programmer, the most common use is four, but it has to be at least one.
#
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error:

# %%
if 5>2:
   print("Five is greater than 2")
   print("Five is greater than 2")

if 5>2:
              print("Five is greater than 2")
# Out:
# Five is greater than 2
# Five is greater than 2
# Five is greater than 2

# %% [markdown]
# --Python Variables--
#
# In Python, a variable is created when you assign a value to it:
# Python has no command for declaring a variable.

# %%
#This is a comment line
x=5
y="Hello World!"

# %% [markdown]
# --statements--
#
# No semicolons are needed for statements in different lines
#
# Both double and single quotes work
#
# By default, the print() function ends with a new line. Use end parameter to avoid newline.

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")

print("Hello World!");print("Have a good day.");print("Learning Python is fun!")

print("This will also work")
print('This will also work!')

print("Hello World! ", end="")
print("This will print in the same line.")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!
# Hello World!
# Have a good day.
# Learning Python is fun!
# This will also work
# This will also work!
# Hello World! This will print in the same line.

# %% [markdown]
# --Print Numbers--
#
# Unlike text, we don't put numbers inside quotes
#
# And can do math inside the print line
#
# Can combine text and numbers in one output  by separating them with a comma

# %%
print(3)
print(3000)

print(3+5)
print(3*5)

print("I am ",23, "years old")
# Out:
# 3
# 3000
# 8
# 15
# I am  23 years old

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!
